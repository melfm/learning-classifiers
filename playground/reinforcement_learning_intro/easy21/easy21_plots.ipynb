# %%
import argparse
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

import easy21_environment as easyEnv
import monte_carlo_control as MC

import matplotlib.pyplot as plt
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib inline

# %%
env = easyEnv.Easy21Env()
agent = MC.MonteCarloAgent(env, num_episodes=10)
# Out:
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Win rate  40.0

# %%
def animate(frame):
    i = agent.num_episodes
    step_size = i
    step_size = max(1, step_size)
    step_size = min(step_size, 2 ** 16)
    # Train the agent inside this function, since we are
    # passing this to the `FuncAnimation`.
    agent.train()

    ax.clear()
    surf =  agent.plot_frame(ax)
    plt.title('MC score:%s frame:%s step_size:%s ' % (float(agent.player_wins)/agent.num_episodes*100, frame, step_size) )
    fig.canvas.draw()
    return surf

# %%
fig = plt.figure("N100")
ax = fig.add_subplot(111, projection='3d')

ani = animation.FuncAnimation(fig, animate, 32, repeat=False)

# note: requires gif writer; swap with plt.show()
ani.save('MC_Agent.gif', writer='imagemagick', fps=3)
# Out:
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Win rate  80.0
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Win rate  140.0
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# Epsilon greedy, exploring
# ...

# %%
from IPython.display import Image
Image(url="MC_Agent.gif")
# Out:
# <img src="MC_Agent.gif"/>
